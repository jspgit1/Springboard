# %% [markdown]
# We use KneiborsClassifier and face_recognition to build a model. This model will be trained by known person pictures. We use some known pictures or unknown pictures to test the trained model. As second step, we will test picture from webcam

# %%
# jsp_kneighbors_face2.ipynb: use mtcnn as face detector for masked face
# Use face_recognition(dlib) to get face encording
# Use KNeighborsClassifier as predictor

import numpy as np
import os
import face_recognition as frg
from sklearn.neighbors import KNeighborsClassifier
import re
import math
import mtcnn
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

def show_face(img_path, location):
    pil_image = Image.open(img_path).convert("RGB")
    (top,right, bottom, left) = location

    draw = ImageDraw.Draw(pil_image)
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))
    display(pil_image)

# %%
# We define a train function

def kntrain(X, y, neighbors, kn_alg):
    if neighbors is None:
        neighbors = int(math.sqrt(len(X)))
    klf1 = KNeighborsClassifier(algorithm=kn_alg, n_neighbors=neighbors, weights='distance')
    klf1.fit(X,y)
    return klf1

# %%
# Use mtcnn and face_recognition.face_locations() to get face bounding boxes
# But only use bounding boxes from mtcnn to get face encoding
import cv2
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# Use MTCNN as face detector
detector = mtcnn.MTCNN()

extension = ['jpg','png','bmp','jpeg']
X =[]
y =[]

for (root,dirs,files) in os.walk('maskedface'):
    pattern = '^\w+/train/\w+'
    if re.match(pattern, root):
        print('root:',root)
        print('files:',files)
        label0 = root.split('/')[-1]
        for imgf in files:
            imgf = imgf.lower()
            if imgf.split('.')[1] in extension:
                imgpath = os.path.join(root, imgf)
                #npimg = plt.imread(imgpath)
                npimg = frg.load_image_file(imgpath, mode='RGB')
                f_location = frg.face_locations(npimg, model='cnn')
                f_location2 = detector.detect_faces(npimg)
                print('len(f_location):',len(f_location))
                
                #If face_recognition.face_locations() detected face box, 
                # we use the box to get encoding                
                if len(f_location) == 1:
                    print('fpath:',imgpath)
                    print('f_location:',f_location)          
                    f_encord = frg.face_encodings(npimg,known_face_locations=f_location)[0]
                    X.append(f_encord)
                    y.append(label0)
                    
                elif len(f_location2) == 1:
                    print('fpath:',imgpath)
                    x1, y1, w, h = f_location2[0]['box']
                    print('x1, y1, w, h:',x1, y1, w, h)
                    m_location = [(y1, x1+w,y1+h, x1)]
                    print('m_location:',m_location)                   
                    f_encord = frg.face_encodings(npimg,known_face_locations=m_location)[0]
                    X.append(f_encord)
                    y.append(label0)
                else:
                    print('fpath:',imgpath)
                    print('Incorrect face image!')    
            else:
                print('File $s has wrong format' % imgf)
  
klf = kntrain(X, y, neighbors=None, kn_alg='ball_tree')
# Out:
# root: maskedface/train/00108
# files: ['001.jpg', '003.jpg', '002.jpg', '014.jpg', '013.jpg', '000.jpg', '009.jpg', '006.jpg', '015.jpg', '010.jpg', '007.jpg', '016.jpg']
# WARNING:tensorflow:5 out of the last 324 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7faea44c5710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 325 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fae50e5a440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# len(f_location): 0
# fpath: maskedface/train/00108/001.jpg
# x1, y1, w, h: 93 18 69 93
# m_location: [(18, 162, 111, 93)]
# len(f_location): 0
# fpath: maskedface/train/00108/003.jpg
# x1, y1, w, h: 111 52 30 35
# m_location: [(52, 141, 87, 111)]
# len(f_location): 1
# fpath: maskedface/train/00108/002.jpg
# f_location: [(36, 186, 134, 88)]
# len(f_location): 0
# fpath: maskedface/train/00108/014.jpg
# x1, y1, w, h: 118 36 38 43
# m_location: [(36, 156, 79, 118)]
# len(f_location): 1
# fpath: maskedface/train/00108/013.jpg
# f_location: [(13, 140, 53, 101)]
# len(f_location): 0
# fpath: maskedface/train/00108/000.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00108/009.jpg
# f_location: [(28, 135, 76, 87)]
# len(f_location): 1
# fpath: maskedface/train/00108/006.jpg
# f_location: [(37, 207, 155, 89)]
# len(f_location): 0
# fpath: maskedface/train/00108/015.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00108/010.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00108/007.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00108/016.jpg
# Incorrect face image!
# root: maskedface/train/00061
# files: ['001.jpg', '002.jpg', '000.jpg']
# len(f_location): 0
# fpath: maskedface/train/00061/001.jpg
# x1, y1, w, h: 148 13 20 22
# m_location: [(13, 168, 35, 148)]
# len(f_location): 0
# fpath: maskedface/train/00061/002.jpg
# x1, y1, w, h: 91 72 65 71
# m_location: [(72, 156, 143, 91)]
# len(f_location): 1
# fpath: maskedface/train/00061/000.jpg
# f_location: [(31, 160, 113, 78)]
# root: maskedface/train/00053
# files: ['008.jpg', '003.jpg', '004.jpg', '002.jpg', '005.jpg', '000.jpg', '009.jpg', '006.jpg', '010.jpg', '007.jpg']
# len(f_location): 1
# fpath: maskedface/train/00053/008.jpg
# f_location: [(53, 149, 100, 102)]
# len(f_location): 0
# fpath: maskedface/train/00053/003.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00053/004.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00053/002.jpg
# x1, y1, w, h: 109 15 31 39
# m_location: [(15, 140, 54, 109)]
# len(f_location): 1
# fpath: maskedface/train/00053/005.jpg
# f_location: [(24, 149, 71, 102)]
# len(f_location): 1
# fpath: maskedface/train/00053/000.jpg
# f_location: [(0, 219, 134, 50)]
# len(f_location): 0
# fpath: maskedface/train/00053/009.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00053/006.jpg
# f_location: [(6, 212, 210, 8)]
# len(f_location): 1
# fpath: maskedface/train/00053/010.jpg
# f_location: [(75, 160, 143, 92)]
# len(f_location): 1
# fpath: maskedface/train/00053/007.jpg
# f_location: [(50, 219, 220, 50)]
# root: maskedface/train/00015
# files: ['008.jpg', '002.jpg', '005.jpg', '000.jpg', '006.jpg', '007.jpg']
# len(f_location): 1
# fpath: maskedface/train/00015/008.jpg
# f_location: [(33, 202, 203, 32)]
# len(f_location): 1
# fpath: maskedface/train/00015/002.jpg
# f_location: [(33, 144, 73, 105)]
# len(f_location): 0
# fpath: maskedface/train/00015/005.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00015/000.jpg
# f_location: [(67, 116, 114, 68)]
# len(f_location): 1
# fpath: maskedface/train/00015/006.jpg
# f_location: [(50, 202, 220, 32)]
# len(f_location): 1
# fpath: maskedface/train/00015/007.jpg
# f_location: [(56, 186, 154, 88)]

# %%
X[0]
# Out:
# array([-0.04324761,  0.05154458,  0.05921972, -0.1028722 , -0.14843708,
#         0.00641776, -0.05143931, -0.08496272,  0.13576284, -0.15990938,
#         0.24186304, -0.05629171, -0.19580197,  0.04143371, -0.09473547,
#         0.17808652, -0.17377399, -0.20676962, -0.00717282,  0.05882799,
#         0.05779311,  0.06446622, -0.00402609,  0.03821346, -0.13230065,
#        -0.34512377, -0.11729855, -0.07265467,  0.00359613, -0.00062308,
#        -0.01634434,  0.02830682, -0.15084916,  0.05897174,  0.08283187,
#         0.05625825,  0.02035939, -0.10987286,  0.20179588,  0.04942165,
#        -0.32917458,  0.07039836,  0.08916241,  0.27459341,  0.10635395,
#        -0.00550528, -0.008766  , -0.14897874,  0.10845071, -0.15438296,
#         0.05658791,  0.13718899,  0.0657168 ,  0.06457416,  0.018567  ,
#        -0.15046906,  0.03878831,  0.15201457, -0.15248455,  0.00632714,
#         0.0409874 ,  0.01014258,  0.04895215, -0.15947618,  0.23346777,
#         0.09255453, -0.12083836, -0.22301003,  0.11561612, -0.13799614,
#        -0.11122329,  0.11356208, -0.20603359, -0.16419716, -0.21065228,
#        -0.01694611,  0.36921766,  0.13298979, -0.1773404 ,  0.0605225 ,
#        -0.00062129, -0.00305876,  0.1067187 ,  0.16542813,  0.02601676,
#         0.06900273, -0.06730232, -0.01313278,  0.29387036, -0.08610686,
#        -0.04820061,  0.21457206, -0.03671506,  0.0597884 ,  0.0209983 ,
#        -0.00510563, -0.07619833,  0.03818512, -0.17857043, -0.04211247,
#        -0.04871279,  0.02013409, -0.03900077,  0.12895904, -0.17945082,
#         0.09739918,  0.00428308, -0.01945314, -0.00900197,  0.06841975,
#        -0.05180985, -0.0602406 ,  0.13030519, -0.22732456,  0.24389829,
#         0.13900472,  0.11906269,  0.09259626,  0.1174031 ,  0.01660679,
#        -0.02466071, -0.02918175, -0.2084932 , -0.02498016,  0.1048913 ,
#        -0.05997818,  0.10989257, -0.01686781])

# %%
# Create test image list
Xt=[]   #Test images encoding
ft=[]   #Test image file path
lt=[]   #Face location in image
for (root,dirs,files) in os.walk('maskedface/test'):
    if (files!=""):
        for f1 in files:
            label1 = f1.split('.')[0]
            f1path = os.path.join(root,f1)
            f1img = frg.load_image_file(f1path, mode='RGB')
            m_locations = detector.detect_faces(f1img)
            print('f1path:',f1path)
            print('len(m_locations):',len(m_locations))
            
            for i in range(len(m_locations)):
                #print('f1path:',f1path)
                x1, y1, w, h = m_locations[i]['box']
                m_location = [(y1, x1+w,y1+h, x1)]
                print('m_location:',m_location)                   
                f_encord = frg.face_encodings(f1img, known_face_locations=m_location)[0]               
                Xt.append(f_encord)
                lt.append(m_location)
                ft.append(f1path)
print(len(Xt))
print(len(lt))
print(ft)
# Out:
# f1path: maskedface/test/00003.jpg
# len(m_locations): 1
# m_location: [(14, 170, 95, 105)]
# f1path: maskedface/test/00033.jpg
# len(m_locations): 0
# f1path: maskedface/test/00054.jpg
# len(m_locations): 1
# m_location: [(29, 157, 98, 95)]
# f1path: maskedface/test/00020.jpg
# len(m_locations): 1
# m_location: [(27, 148, 55, 125)]
# f1path: maskedface/test/00009.jpg
# len(m_locations): 1
# m_location: [(53, 168, 118, 112)]
# f1path: maskedface/test/00013.jpg
# len(m_locations): 1
# m_location: [(80, 48, 119, 14)]
# f1path: maskedface/test/00063.jpg
# len(m_locations): 1
# m_location: [(4, 218, 171, 75)]
# f1path: maskedface/test/00052.jpg
# len(m_locations): 1
# m_location: [(17, 133, 128, 40)]
# f1path: maskedface/test/00015.jpg
# len(m_locations): 1
# m_location: [(24, 147, 59, 116)]
# f1path: maskedface/test/00108.jpg
# len(m_locations): 1
# m_location: [(36, 156, 79, 118)]
# f1path: maskedface/test/00102.jpg
# len(m_locations): 0
# f1path: maskedface/test/00023.jpg
# len(m_locations): 1
# m_location: [(47, 133, 99, 88)]
# f1path: maskedface/test/00053.jpg
# len(m_locations): 1
# m_location: [(35, 165, 134, 86)]
# 11
# 11
# ['maskedface/test/00003.jpg', 'maskedface/test/00054.jpg', 'maskedface/test/00020.jpg', 'maskedface/test/00009.jpg', 'maskedface/test/00013.jpg', 'maskedface/test/00063.jpg', 'maskedface/test/00052.jpg', 'maskedface/test/00015.jpg', 'maskedface/test/00108.jpg', 'maskedface/test/00023.jpg', 'maskedface/test/00053.jpg']

# %%
lt[1]
# Out:
# [(29, 157, 98, 95)]

# %%
# This funcation can show the real image size inline
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

def show_labels_on_image2(img_path, location, label_index):
    pil_image = Image.open(img_path).convert("RGB")
    print('location:',location)
    [(top,right, bottom, left)] = location
    name = y[label_index]     # get predicted name
    #name = name.encode("UTF-8")
    draw = ImageDraw.Draw(pil_image)
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))
    # Define font type and size. The font file is in my ubuntu 18.04. Font size is 14
    font_file = '/usr/share/fonts/truetype/freefont/FreeSansBold.ttf'
    font = ImageFont.truetype(font_file, 14)
    text_w,text_h = font.getsize(name)
    #text_width, text_height = draw.textsize(name)
    
    draw.text((left + 5, bottom + text_h), name, font=font, fill=(000, 255, 255, 125))

    #Below will pop up a image window
    #pil_image.show()
    #Below shows image inline
    display(pil_image)

# %%
dist_threshold = 0.5
xt = Xt[0].reshape(1,-1)
closest_distance = klf.kneighbors(xt, n_neighbors=1, return_distance=True)
if closest_distance[0][0][0] <= dist_threshold :
    # Below closest_distance[1][0][0] is label (y) indices
    show_labels_on_image2(ft[0], lt[0], closest_distance[1][0][0])
    
print('Test image:', ft[0])
# Out:
# Test image: maskedface/test/00003.jpg

# %%
# Test all images in test matrix
dist_threshold = 0.65
for i in range(len(Xt)):
    xt = Xt[i].reshape(1,-1)
    closest_distance = klf.kneighbors(xt, n_neighbors=1, return_distance=True)
    if closest_distance[0][0][0] <= dist_threshold:
        # Below closest_distance[1][0][0] is label (y) indices
        print('Test image:', ft[i]) 
        show_labels_on_image2(ft[i], lt[i], closest_distance[1][0][0])
# Out:
# Test image: maskedface/test/00003.jpg
# location: [(14, 170, 95, 105)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE50249390>
# Test image: maskedface/test/00054.jpg
# location: [(29, 157, 98, 95)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE6CD1FB90>
# Test image: maskedface/test/00020.jpg
# location: [(27, 148, 55, 125)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE6C851050>
# Test image: maskedface/test/00009.jpg
# location: [(53, 168, 118, 112)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE2C815710>
# Test image: maskedface/test/00013.jpg
# location: [(80, 48, 119, 14)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE6C851050>
# Test image: maskedface/test/00063.jpg
# location: [(4, 218, 171, 75)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE2C120350>
# Test image: maskedface/test/00052.jpg
# location: [(17, 133, 128, 40)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE6CFD8390>
# Test image: maskedface/test/00015.jpg
# location: [(24, 147, 59, 116)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE6CD1F450>
# Test image: maskedface/test/00108.jpg
# location: [(36, 156, 79, 118)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE2C815250>
# Test image: maskedface/test/00023.jpg
# location: [(47, 133, 99, 88)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE2C815250>
# Test image: maskedface/test/00053.jpg
# location: [(35, 165, 134, 86)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAE50249390>
