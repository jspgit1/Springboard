# %% [markdown]
# We use KneiborsClassifier and face_recognition to build a model. This model will be trained by known person pictures. We use some known pictures or unknown pictures to test the trained model. As second step, we will test picture from webcam

# %%
# jsp_kneighbors_face2.ipynb: use dlib and mtcnn as face detector for masked face
# Use face_recognition(dlib) to get face encording
# Use KNeighborsClassifier as predictor

import numpy as np
import os
import face_recognition as frg
from sklearn.neighbors import KNeighborsClassifier
import re
import math
import mtcnn
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

def show_face(img_path, location):
    pil_image = Image.open(img_path).convert("RGB")
    (top,right, bottom, left) = location

    draw = ImageDraw.Draw(pil_image)
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))
    display(pil_image)

# %%
# We define a train function

def kntrain(X, y, neighbors, kn_alg):
    if neighbors is None:
        neighbors = int(math.sqrt(len(X)))
    klf1 = KNeighborsClassifier(algorithm=kn_alg, n_neighbors=neighbors, weights='distance')
    klf1.fit(X,y)
    return klf1

# %%
# Use mtcnn and face_recognition.face_locations() to get face bounding boxes
# use face_recognition.face_encodings() to get face encoding
import cv2
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# Use MTCNN as face detector
detector = mtcnn.MTCNN()

extension = ['jpg','png','bmp','jpeg']
X =[]
y =[]

for (root,dirs,files) in os.walk('maskedface2'):
    pattern = '^\w+/train/\w+'
    if re.match(pattern, root):
        print('root:',root)
        print('files:',files)
        label0 = root.split('/')[-1]
        for imgf in files:
            imgf = imgf.lower()
            if imgf.split('.')[1] in extension:
                imgpath = os.path.join(root, imgf)
                #npimg = plt.imread(imgpath)
                npimg = frg.load_image_file(imgpath, mode='RGB')
                f_location = frg.face_locations(npimg, model='cnn')
                f_location2 = detector.detect_faces(npimg)
                print('len(f_location):',len(f_location))
                
                #If face_recognition.face_locations() detected face box, 
                # we use the box to get encoding                
                if len(f_location) == 1:
                    print('fpath:',imgpath)
                    print('f_location:',f_location)          
                    f_encord = frg.face_encodings(npimg,known_face_locations=f_location)[0]
                    X.append(f_encord)
                    y.append(label0)
                    
                elif len(f_location2) == 1:
                    print('len(f_location2):',len(f_location2))
                    print('fpath:',imgpath)
                    x1, y1, w, h = f_location2[0]['box']
                    print('x1, y1, w, h:',x1, y1, w, h)
                    m_location = [(y1, x1+w,y1+h, x1)]
                    print('m_location:',m_location)                   
                    f_encord = frg.face_encodings(npimg,known_face_locations=m_location)[0]
                    X.append(f_encord)
                    y.append(label0)
                else:
                    print('fpath:',imgpath)
                    print('Incorrect face image!')    
            else:
                print('File $s has wrong format' % imgf)
  
klf = kntrain(X, y, neighbors=None, kn_alg='ball_tree')
# Out:
# root: maskedface/train/00023
# files: ['001.jpg', '008.jpg', '003.jpg', '004.jpg', '002.jpg', '005.jpg', '000.jpg', '009.jpg', '006.jpg', '007.jpg']
# WARNING:tensorflow:5 out of the last 272 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f12f81b7320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f12f80e6290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# len(f_location): 1
# fpath: maskedface/train/00023/001.jpg
# f_location: [(46, 146, 144, 48)]
# len(f_location): 1
# fpath: maskedface/train/00023/008.jpg
# f_location: [(62, 164, 110, 116)]
# len(f_location): 1
# fpath: maskedface/train/00023/003.jpg
# f_location: [(42, 139, 99, 82)]
# len(f_location): 1
# fpath: maskedface/train/00023/004.jpg
# f_location: [(68, 167, 136, 99)]
# len(f_location): 0
# len(f_location2): 1
# fpath: maskedface/train/00023/002.jpg
# x1, y1, w, h: 8 55 15 16
# m_location: [(55, 23, 71, 8)]
# len(f_location): 0
# fpath: maskedface/train/00023/005.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00023/000.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00023/009.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00023/006.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00023/007.jpg
# f_location: [(27, 171, 231, 0)]
# root: maskedface/train/00053
# files: ['008.jpg', '003.jpg', '004.jpg', '002.jpg', '005.jpg', '000.jpg', '009.jpg', '006.jpg', '010.jpg', '007.jpg']
# len(f_location): 1
# fpath: maskedface/train/00053/008.jpg
# f_location: [(53, 149, 100, 102)]
# len(f_location): 0
# fpath: maskedface/train/00053/003.jpg
# Incorrect face image!
# len(f_location): 0
# fpath: maskedface/train/00053/004.jpg
# Incorrect face image!
# len(f_location): 0
# len(f_location2): 1
# fpath: maskedface/train/00053/002.jpg
# x1, y1, w, h: 109 15 31 39
# m_location: [(15, 140, 54, 109)]
# len(f_location): 1
# fpath: maskedface/train/00053/005.jpg
# f_location: [(24, 149, 71, 102)]
# len(f_location): 1
# fpath: maskedface/train/00053/000.jpg
# f_location: [(0, 219, 134, 50)]
# len(f_location): 0
# fpath: maskedface/train/00053/009.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00053/006.jpg
# f_location: [(6, 212, 210, 8)]
# len(f_location): 1
# fpath: maskedface/train/00053/010.jpg
# f_location: [(75, 160, 143, 92)]
# len(f_location): 1
# fpath: maskedface/train/00053/007.jpg
# f_location: [(50, 219, 220, 50)]
# root: maskedface/train/00015
# files: ['008.jpg', '002.jpg', '005.jpg', '000.jpg', '006.jpg', '007.jpg']
# len(f_location): 1
# fpath: maskedface/train/00015/008.jpg
# f_location: [(33, 202, 203, 32)]
# len(f_location): 1
# fpath: maskedface/train/00015/002.jpg
# f_location: [(33, 144, 73, 105)]
# len(f_location): 0
# fpath: maskedface/train/00015/005.jpg
# Incorrect face image!
# len(f_location): 1
# fpath: maskedface/train/00015/000.jpg
# f_location: [(67, 116, 114, 68)]
# len(f_location): 1
# fpath: maskedface/train/00015/006.jpg
# f_location: [(50, 202, 220, 32)]
# len(f_location): 1
# fpath: maskedface/train/00015/007.jpg
# f_location: [(56, 186, 154, 88)]

# %%
X[1]
# Out:
# array([-0.18582594,  0.13987686,  0.02878121, -0.05056384, -0.17074805,
#         0.05597166, -0.07287556, -0.11204351,  0.16033962, -0.10932802,
#         0.20182672, -0.03063055, -0.11806309, -0.04995988, -0.04811907,
#         0.18939176, -0.17375754, -0.17590684,  0.00879585, -0.02759909,
#         0.09255775, -0.02153626,  0.00493145,  0.08868068, -0.17346354,
#        -0.33327541, -0.07020348, -0.11992916,  0.03801182, -0.09020101,
#        -0.09048025, -0.00633523, -0.15608126, -0.02067632,  0.00339392,
#         0.08465922,  0.01970208, -0.05556687,  0.19070473,  0.02908353,
#        -0.29107928,  0.06455263,  0.05932416,  0.26446646,  0.14406264,
#        -0.022228  , -0.00217562, -0.07566015,  0.12699144, -0.14918388,
#         0.0388004 ,  0.1440362 ,  0.09503871,  0.04807476,  0.01667649,
#        -0.08313555,  0.03886627,  0.09270274, -0.16115737, -0.00428273,
#         0.09070466, -0.06078785,  0.04253327, -0.08534614,  0.17114557,
#         0.13228652, -0.04211934, -0.19156045,  0.05195266, -0.12811907,
#        -0.06702421,  0.09980068, -0.11162023, -0.19376206, -0.23469307,
#         0.03501984,  0.39015087,  0.21266666, -0.20863348,  0.00570331,
#        -0.05304785, -0.05856315,  0.13244817,  0.12579574, -0.0056997 ,
#         0.05653899, -0.09284168, -0.02229379,  0.2285631 , -0.02407614,
#         0.01877972,  0.23208174,  0.0661355 ,  0.03027161,  0.03235459,
#         0.05825802, -0.12991439,  0.03126083, -0.10292181, -0.06190611,
#        -0.06502321, -0.02169034,  0.00932671,  0.07812573, -0.22887196,
#         0.13587371, -0.01117763, -0.02079185, -0.08096215,  0.05664311,
#        -0.03245843, -0.05465525,  0.10266786, -0.19893532,  0.11561023,
#         0.19587627,  0.05112144,  0.14508797,  0.11736889,  0.04082191,
#        -0.03439892, -0.02494373, -0.10582532, -0.0228381 ,  0.09085111,
#        -0.08038983,  0.07721122,  0.01082006])

# %%
# Create test image list by using mtcnn and dlib face detector
Xt=[]   #Test images encoding
ft=[]   #Test image file path
lt=[]   #Face location in image
for (root,dirs,files) in os.walk('maskedface/test'):
    if (files!=""):
        for f1 in files:
            label1 = f1.split('.')[0]
            f1path = os.path.join(root,f1)
            f1img = frg.load_image_file(f1path, mode='RGB')
            f_locations = frg.face_locations(f1img, model='cnn')
            m_locations = detector.detect_faces(f1img)
            print('len(f_locations):', len(f_locations))
            print('len(m_locations):', len(m_locations))
           
            if len(f_locations) > 0:
                for i in range(len(f_locations)):
                    print('f1path:',f1path)
                    print('f_location:',f_locations[i])                   
                    f_encord = frg.face_encodings(f1img, known_face_locations=[f_locations[i]])[0]               
                    Xt.append(f_encord)
                    lt.append([f_locations[i]])
                    ft.append(f1path)
            elif len(m_locations) > 0:
                for j in range(len(m_locations)):
                    print('mpath:',f1path)
                    x1, y1, w, h = m_locations[j]['box']
                    m_location = [(y1, x1+w,y1+h, x1)]
                    print('m_location:',m_location)                   
                    f_encord = frg.face_encodings(f1img, known_face_locations=m_location)[0]               
                    Xt.append(f_encord)
                    lt.append(m_location)
                    ft.append(f1path) 
            #else:
                #print('fpath:',imgpath)
               # print('Incorrect face image!')              
            

print(len(Xt))
print(len(lt))
print(ft)
# Out:
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00003.jpg
# f_location: (14, 176, 96, 94)
# len(f_locations): 0
# len(m_locations): 0
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00054.jpg
# f_location: (38, 149, 86, 102)
# len(f_locations): 0
# len(m_locations): 1
# mpath: maskedface/test/00020.jpg
# m_location: [(27, 148, 55, 125)]
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00009.jpg
# f_location: (47, 167, 115, 99)
# len(f_locations): 0
# len(m_locations): 1
# mpath: maskedface/test/00013.jpg
# m_location: [(80, 48, 119, 14)]
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00063.jpg
# f_location: (15, 226, 156, 84)
# len(f_locations): 0
# len(m_locations): 1
# mpath: maskedface/test/00052.jpg
# m_location: [(17, 133, 128, 40)]
# len(f_locations): 0
# len(m_locations): 1
# mpath: maskedface/test/00015.jpg
# m_location: [(24, 147, 59, 116)]
# len(f_locations): 0
# len(m_locations): 1
# mpath: maskedface/test/00108.jpg
# m_location: [(36, 156, 79, 118)]
# len(f_locations): 0
# len(m_locations): 0
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00023.jpg
# f_location: (42, 139, 99, 82)
# len(f_locations): 1
# len(m_locations): 1
# f1path: maskedface/test/00053.jpg
# f_location: (39, 160, 121, 78)
# 11
# 11
# ['maskedface/test/00003.jpg', 'maskedface/test/00054.jpg', 'maskedface/test/00020.jpg', 'maskedface/test/00009.jpg', 'maskedface/test/00013.jpg', 'maskedface/test/00063.jpg', 'maskedface/test/00052.jpg', 'maskedface/test/00015.jpg', 'maskedface/test/00108.jpg', 'maskedface/test/00023.jpg', 'maskedface/test/00053.jpg']

# %%
lt[1]
# Out:
# (38, 149, 86, 102)

# %%
# This funcation can show the real image size inline
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

def show_labels_on_image2(img_path, location, label_index):
    pil_image = Image.open(img_path).convert("RGB")
    #location must be in format: [(top,right, bottom, left)]
    print('location:',location)
    [(top,right, bottom, left)] = location
    name = y[label_index]     # get predicted name
    #name = name.encode("UTF-8")
    draw = ImageDraw.Draw(pil_image)
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))
    # Define font type and size. The font file is in my ubuntu 18.04. Font size is 14
    font_file = '/usr/share/fonts/truetype/freefont/FreeSansBold.ttf'
    font = ImageFont.truetype(font_file, 16)
    text_w,text_h = font.getsize(name)
    #text_width, text_height = draw.textsize(name)
    
    draw.text((left + 5, bottom + text_h), name, font=font, fill=(000, 255, 255, 125))

    #Below will pop up a image window
    #pil_image.show()
    #Below shows image inline
    display(pil_image)

# %%
dist_threshold = 0.5
xt = Xt[0].reshape(1,-1)
closest_distance = klf.kneighbors(xt, n_neighbors=1, return_distance=True)
if closest_distance[0][0][0] <= dist_threshold :
    # Below closest_distance[1][0][0] is label (y) indices
    show_labels_on_image2(ft[0], lt[0], closest_distance[1][0][0])
    
print('Test image:', ft[0])
# Out:
# Test image: maskedface/test/00003.jpg

# %%
# Test all images in test matrix
dist_threshold = 0.40
for i in range(len(Xt)):
    xt = Xt[i].reshape(1,-1)
    closest_distance = klf.kneighbors(xt, n_neighbors=1, return_distance=True)
    if closest_distance[0][0][0] <= dist_threshold:
        # Below closest_distance[1][0][0] is label (y) indices
        print('Test image:', ft[i]) 
        show_labels_on_image2(ft[i], lt[i], closest_distance[1][0][0])
# Out:
# Test image: maskedface/test/00063.jpg
# location: [(15, 226, 156, 84)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F12F83EF9D0>
# Test image: maskedface/test/00015.jpg
# location: [(24, 147, 59, 116)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F12F80BAF50>
# Test image: maskedface/test/00108.jpg
# location: [(36, 156, 79, 118)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F12F83EFE10>
# Test image: maskedface/test/00023.jpg
# location: [(42, 139, 99, 82)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F12F81F5850>
# Test image: maskedface/test/00053.jpg
# location: [(39, 160, 121, 78)]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F13097D0E90>
